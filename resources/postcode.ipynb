# %%
import json
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Read the postcode from raw csv

# %%
raw_postcode_data = pd.read_csv('australian_postcodes.csv')
raw_postcode_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 18443 non-null  int64
#  1   postcode           18443 non-null  int64
#  2   locality           18443 non-null  object
#  3   state              18443 non-null  object
#  4   long               18443 non-null  float64
#  5   lat                18443 non-null  float64
#  6   dc                 17883 non-null  object
#  7   type               16805 non-null  object
#  8   status             18404 non-null  object
#  9   sa3                18045 non-null  float64
#  10  sa3name            18045 non-null  object
#  11  sa4                18045 non-null  float64
#  12  sa4name            18045 non-null  object
#  13  region             18276 non-null  object
#  14  Lat_precise        18252 non-null  float64
#  15  Long_precise       18252 non-null  float64
# ...

# %%
raw_postcode_data.head(5)
# Out:
#       id  postcode                        locality state        long  \
# 0    230       200                             ANU   ACT  149.119000
# 1  21820       200  Australian National University   ACT  149.118900
# 2    232       800                          DARWIN    NT  130.836680
# 3    233       801                          DARWIN    NT  130.836680
# 4    234       804                           PARAP    NT  130.873315
#
#          lat   dc type                   status      sa3  ...   SA3_NAME_2016  \
# 0 -35.277700  NaN  NaN                      NaN      NaN  ...  North Canberra
# 1 -35.277700  NaN  NaN        Added 19-Jan-2020      NaN  ...  North Canberra
# 2 -12.458684  NaN  NaN       Updated 6-Feb-2020  70101.0  ...     Darwin City
# 3 -12.458684  NaN  NaN  Updated 25-Mar-2020 SA3  70101.0  ...     Darwin City
# 4 -12.428017  NaN  NaN  Updated 25-Mar-2020 SA3  70102.0  ...     Darwin City
#
#    SA4_CODE_2016                 SA4_NAME_2016 RA_2011  RA_2016  MMM_2015  \
# ...

# %%
ready_postcode_data = raw_postcode_data[['postcode','locality','state','long','lat']]
ready_postcode_data
# Out:
#        postcode                        locality state        long        lat
# 0           200                             ANU   ACT  149.119000 -35.277700
# 1           200  Australian National University   ACT  149.118900 -35.277700
# 2           800                          DARWIN    NT  130.836680 -12.458684
# 3           801                          DARWIN    NT  130.836680 -12.458684
# 4           804                           PARAP    NT  130.873315 -12.428017
# ...         ...                             ...   ...         ...        ...
# 18438      9013                        BRISBANE   QLD  152.823141 -27.603479
# 18439      9015                        BRISBANE   QLD  152.823141 -27.603479
# 18440      9464                    NORTHGATE MC   QLD  153.074982 -27.397055
# 18441      9726                   GOLD COAST MC   QLD  153.412197 -28.008783
# 18442      9999                      NORTH POLE   VIC  144.956776 -37.817403
#
# [18443 rows x 5 columns]

# %%
ready_postcode_data.to_csv('ready_postcode.csv')

# %%
#read the csv file only have nsw and vic data
postcode_data = pd.read_csv('nsw&vic_postcode.csv')
postcode_data.head()
# Out:
#    postcode locality state        long        lat Category
# 0      1001   SYDNEY   NSW  151.268071 -33.794883      NaN
# 1      1002   SYDNEY   NSW  151.268071 -33.794883      NaN
# 2      1003   SYDNEY   NSW  151.268071 -33.794883      NaN
# 3      1004   SYDNEY   NSW  151.268071 -33.794883      NaN
# 4      1005   SYDNEY   NSW  151.268071 -33.794883      NaN

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a array
    data = []
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
            
            data.append(rows)
             
 
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'nsw&vic_postcode.csv'
jsonFilePath = r'final.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
